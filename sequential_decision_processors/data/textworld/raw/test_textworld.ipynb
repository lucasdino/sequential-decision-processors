# %%
import json, os
from typing import Optional, Dict, Any, List
import utils as util

from scienceworld import ScienceWorldEnv
from textworld import EnvInfos

# from alfworld.agents.environment import get_environment
# import alfworld.agents.modules.generic as generic

# %%
# Testing out resetting of science world
sw_jar_path = os.path.join(os.getcwd(), "tw_games", "scienceworld.jar")
sw_env = ScienceWorldEnv(
    taskName="", serverPath=sw_jar_path, envStepLimit=100
)

taskName = 'boil'
var_num = 5
simplification_str = ""

sw_env.load(taskName, var_num, simplification_str, generateGoldPath=True)
obs, info = sw_env.reset()

print(obs)
print(info['taskDesc'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Testing out resetting of science world
#       2 sw_jar_path = os.path.join(os.getcwd(), "tw_games", "scienceworld.jar")
# ----> 3 sw_env = ScienceWorldEnv(
#       4     taskName="", serverPath=sw_jar_path, envStepLimit=100
#       5 )
#       7 taskName = 'boil'
#       8 var_num = 5
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py:65, in ScienceWorldEnv.__init__(self, taskName, serverPath, envStepLimit)
#      58 # Tell the Java side to connect to the python callback server with the new
#      59 # python port. Note that we use the java_gateway_server attribute that
#      60 # retrieves the GatewayServer instance.
#      61 self._gateway.java_gateway_server.resetCallbackClient(
#      62     self._gateway.java_gateway_server.getCallbackClient().getAddress(),
#      63     python_port)
# ---> 65 self.server = self._gateway.jvm.scienceworld.runtime.pythonapi.PythonInterface()
#      66 logger.info("ScienceWorld server running on port %d", port)
#      68 # Keep track of the last step score, to calculate reward from score
#
# TypeError: 'JavaPackage' object is not callable

# %%
taskName = 'boil'
var_num = 8
simplification_str = ""


sw_env.load(taskName, var_num, simplification_str, generateGoldPath=True)
obs, info = sw_env.reset()


print(obs)
print(info['taskDesc'])
# Out:
# This room is called the bathroom. In it, you see:
# 	the agent
# 	a substance called air
# 	a bathtub, which is turned off. In the bathtub is: nothing.
# 	a glass cup (containing nothing)
# 	a picture
# 	a sink, which is turned off. In the sink is: nothing.
# 	a toilet. In the toilet is: A drain, which is open, a substance called water.
# You also see:
# 	A door to the kitchen (that is closed)
# Task Description:
# Your task is to boil apple juice. For compounds without a boiling point, combusting the substance is also acceptable. First, focus on the substance. Then, take actions that will cause it to change its state of matter.

# %% [markdown]
# # Textworld

# %% [markdown]
# ### Test Data Creation

# %%
num_gens = 1

# Define our inputs
save_path = f"{os.getcwd()}/generated_data"
sampling_args = [
    util.SamplingArgs(name="cooking_singlemove", max_samples_per_env=20, rollout_length=1, total_samples=25, max_step_overlap=0),
    util.SamplingArgs(name="cooking_multimove", max_samples_per_env=8, rollout_length=5, total_samples=25, max_step_overlap=1),
]
cooking_wrapper = util.Textworld_Cooking_Wrapper_Env()

# Generate our data
data_sampler = util.Textworld_Sampling_Manager(
    wrapper = cooking_wrapper,
    sampling_args=sampling_args
)

for i in range(num_gens):
    data_sampler.generate_data(save_path=save_path, max_iters=None)

# %% [markdown]
# ### Wrapper

# %%
test_cooking_wrapper = False

if test_cooking_wrapper:
    cooking_wrapper = util.Textworld_Cooking_Wrapper_Env()

    # Generate new game and load env in
    cooking_wrapper.generate_new_game(randomize_gen_args=True)
    cooking_wrapper.load_env()

    while not cooking_wrapper.game_state.done:
        cooking_wrapper.step_env()
        if cooking_wrapper.game_state.moves == 10:
            print(cooking_wrapper.get_env_state(full_state=True))
        else:
           print(cooking_wrapper.get_env_state(full_state=False))

# %% [markdown]
# ### Playable Textworld

# %%
test_playable_tw = False

if test_playable_tw:
    play_textworld = True

    # Setup wrapper and env
    cooking_wrapper = util.Textworld_Cooking_Wrapper_Env()
    cooking_gen_args = {
        "recipe": 5,
        "take": 3,
        "go": 1,
        "open_": True,
        "cook": True,
        "cut": True,
        "drop": True
    }
    cooking_wrapper.generate_new_game(
       randomize_gen_args=False,
       game_gen_args=cooking_gen_args
    )
    cooking_wrapper.load_env()
    
    # Print initial state
    util.print_env_state(cooking_wrapper.get_env_state(full_state=True))
    
    # Main play loop
    done = False
    while not done:
        if play_textworld:
            command = input("> ")
        else:
            command = None
        if command == "stop":
            break
        done = cooking_wrapper.step_env(command)
        util.print_env_state(cooking_wrapper.get_env_state(full_state=False))

# %% [markdown]
# # Science World

# %% [markdown]
# ### Test Data Creation

# %%
num_gens = 1

# Define our inputs
save_path = f"{os.getcwd()}/generated_data"
sampling_args = [
    util.SamplingArgs(name="scienceworld_singlemove", max_samples_per_env=20, rollout_length=1, total_samples=25, max_step_overlap=0),
    util.SamplingArgs(name="scienceworld_multimove", max_samples_per_env=8, rollout_length=5, total_samples=25, max_step_overlap=1),
]
scienceworld_wrapper = util.Scienceworld_Wrapper_Env()

# Generate our data
data_sampler = util.Textworld_Sampling_Manager(
    wrapper = scienceworld_wrapper,
    sampling_args=sampling_args
)

for i in range(num_gens):
    data_sampler.generate_data(save_path=save_path, max_iters=None)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1255, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19335/1753770829.py", line 18, in <module>
#     data_sampler.generate_data(save_path=save_path, max_iters=None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 66, in generate_data
#     self._generate_samples()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 99, in _generate_samples
#     self.wrapper.reset_env()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py", line 295, in reset_env
#     env_response, env_state = self.env.reset()
#                               ^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py", line 140, in reset
#     self.server.reset()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1361, in __call__
#     answer = self.gateway_client.send_command(command)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1104, in send_command
#     connection.shutdown_socket(local_addr[1], remote_addr[1])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1255, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1268, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
# ValueError: I/O operation on closed file.
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3721, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1179, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1050, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 858, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 743, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 800, in get_records
#     style = stack_data.style_with_executing_node(base_style, self.tb_highlight)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 455, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 112, in __new__
#     ndef[4] = colorformat(styledef[3:])
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 66, in colorformat
#     def colorformat(text):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1400, in <lambda>
#     _garbage_collect_object and _garbage_collect_object(cc, id))
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 650, in _garbage_collect_object
#     gateway_client.garbage_collect_object(target_id)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 969, in garbage_collect_object
#     self.send_command(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1059, in send_command
#     logging.exception(
# Message: 'Exception while sending command.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1255, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19335/1753770829.py", line 18, in <module>
#     data_sampler.generate_data(save_path=save_path, max_iters=None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 66, in generate_data
#     self._generate_samples()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 99, in _generate_samples
#     self.wrapper.reset_env()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py", line 295, in reset_env
#     env_response, env_state = self.env.reset()
#                               ^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py", line 140, in reset
#     self.server.reset()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1361, in __call__
#     answer = self.gateway_client.send_command(command)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1104, in send_command
#     connection.shutdown_socket(local_addr[1], remote_addr[1])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 982, in _get_connection
#     connection = self.deque.pop()
#                  ^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1170, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
# ValueError: I/O operation on closed file.
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3721, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1179, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1050, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 858, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 743, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 800, in get_records
#     style = stack_data.style_with_executing_node(base_style, self.tb_highlight)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 455, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 112, in __new__
#     ndef[4] = colorformat(styledef[3:])
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 66, in colorformat
#     def colorformat(text):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1400, in <lambda>
#     _garbage_collect_object and _garbage_collect_object(cc, id))
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 650, in _garbage_collect_object
#     gateway_client.garbage_collect_object(target_id)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 969, in garbage_collect_object
#     self.send_command(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1036, in send_command
#     connection = self._get_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 984, in _get_connection
#     connection = self._create_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 990, in _create_connection
#     connection.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1181, in start
#     logger.exception(msg)
# Message: 'An error occurred while trying to connect to the Java server (127.0.0.1:36919)'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1255, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19335/1753770829.py", line 18, in <module>
#     data_sampler.generate_data(save_path=save_path, max_iters=None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 66, in generate_data
#     self._generate_samples()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 99, in _generate_samples
#     self.wrapper.reset_env()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py", line 295, in reset_env
#     env_response, env_state = self.env.reset()
#                               ^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py", line 140, in reset
#     self.server.reset()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1361, in __call__
#     answer = self.gateway_client.send_command(command)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1104, in send_command
#     connection.shutdown_socket(local_addr[1], remote_addr[1])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 982, in _get_connection
#     connection = self.deque.pop()
#                  ^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1170, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
# ValueError: I/O operation on closed file.
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3721, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1179, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1050, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 858, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 743, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 800, in get_records
#     style = stack_data.style_with_executing_node(base_style, self.tb_highlight)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 455, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 112, in __new__
#     ndef[4] = colorformat(styledef[3:])
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 66, in colorformat
#     def colorformat(text):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1400, in <lambda>
#     _garbage_collect_object and _garbage_collect_object(cc, id))
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 650, in _garbage_collect_object
#     gateway_client.garbage_collect_object(target_id)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 969, in garbage_collect_object
#     self.send_command(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1036, in send_command
#     connection = self._get_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 984, in _get_connection
#     connection = self._create_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 990, in _create_connection
#     connection.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1181, in start
#     logger.exception(msg)
# Message: 'An error occurred while trying to connect to the Java server (127.0.0.1:36919)'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1255, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19335/1753770829.py", line 18, in <module>
#     data_sampler.generate_data(save_path=save_path, max_iters=None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 66, in generate_data
#     self._generate_samples()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 99, in _generate_samples
#     self.wrapper.reset_env()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py", line 295, in reset_env
#     env_response, env_state = self.env.reset()
#                               ^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py", line 140, in reset
#     self.server.reset()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1361, in __call__
#     answer = self.gateway_client.send_command(command)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1104, in send_command
#     connection.shutdown_socket(local_addr[1], remote_addr[1])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 982, in _get_connection
#     connection = self.deque.pop()
#                  ^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1170, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
# ValueError: I/O operation on closed file.
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3721, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1179, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1050, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 858, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 743, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 800, in get_records
#     style = stack_data.style_with_executing_node(base_style, self.tb_highlight)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 455, in style_with_executing_node
#     class NewStyle(style):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 112, in __new__
#     ndef[4] = colorformat(styledef[3:])
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/pygments/style.py", line 66, in colorformat
#     def colorformat(text):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1400, in <lambda>
#     _garbage_collect_object and _garbage_collect_object(cc, id))
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 650, in _garbage_collect_object
#     gateway_client.garbage_collect_object(target_id)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 969, in garbage_collect_object
#     self.send_command(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1036, in send_command
#     connection = self._get_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 984, in _get_connection
#     connection = self._create_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 990, in _create_connection
#     connection.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1181, in start
#     logger.exception(msg)
# Message: 'An error occurred while trying to connect to the Java server (127.0.0.1:36919)'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1255, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19335/1753770829.py", line 18, in <module>
#     data_sampler.generate_data(save_path=save_path, max_iters=None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 66, in generate_data
#     self._generate_samples()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 99, in _generate_samples
#     self.wrapper.reset_env()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py", line 295, in reset_env
#     env_response, env_state = self.env.reset()
#                               ^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py", line 140, in reset
#     self.server.reset()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1361, in __call__
#     answer = self.gateway_client.send_command(command)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1104, in send_command
#     connection.shutdown_socket(local_addr[1], remote_addr[1])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 982, in _get_connection
#     connection = self.deque.pop()
#                  ^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1170, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
# ValueError: I/O operation on closed file.
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# ...
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/socket.py", line 707, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19335/1753770829.py", line 18, in <module>
#     data_sampler.generate_data(save_path=save_path, max_iters=None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 66, in generate_data
#     self._generate_samples()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py", line 99, in _generate_samples
#     self.wrapper.reset_env()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py", line 295, in reset_env
#     env_response, env_state = self.env.reset()
#                               ^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py", line 140, in reset
#     self.server.reset()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1361, in __call__
#     answer = self.gateway_client.send_command(command)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1104, in send_command
#     connection.shutdown_socket(local_addr[1], remote_addr[1])
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 982, in _get_connection
#     connection = self.deque.pop()
#                  ^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1170, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
# ValueError: I/O operation on closed file.
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3721, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2194, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1179, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1050, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 858, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 743, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/IPython/core/ultratb.py", line 845, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 587, in mapper
#     return cls(f, options)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/stack_data/core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/executing/executing.py", line 224, in executing
#     source = cls.for_frame(frame)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/executing/executing.py", line 143, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/executing/executing.py", line 172, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/executing/executing.py", line 183, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/executing/executing.py", line 127, in __init__
#     for node in ast.walk(self.tree):
#   File "/usr/lib/python3.12/ast.py", line 379, in walk
#     todo.extend(iter_child_nodes(node))
#   File "/usr/lib/python3.12/ast.py", line 280, in iter_child_nodes
#     yield item
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1400, in <lambda>
#     _garbage_collect_object and _garbage_collect_object(cc, id))
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 650, in _garbage_collect_object
#     gateway_client.garbage_collect_object(target_id)
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 969, in garbage_collect_object
#     self.send_command(
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1036, in send_command
#     connection = self._get_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 984, in _get_connection
#     connection = self._create_connection()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 990, in _create_connection
#     connection.start()
#   File "/home/lucas/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1181, in start
#     logger.exception(msg)
# Message: 'An error occurred while trying to connect to the Java server (127.0.0.1:36919)'
# Arguments: ()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1255, in GatewayConnection.send_command(self, command)
#    1254 try:
# -> 1255     answer = smart_decode(self.stream.readline()[:-1])
#    1256     logger.debug("Answer received: {0}".format(answer))
#
# File /usr/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     706 try:
# --> 707     return self._sock.recv_into(b)
#     708 except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 18
#      12 data_sampler = util.Textworld_Sampling_Manager(
#      13     wrapper = scienceworld_wrapper,
#      14     sampling_args=sampling_args
#      15 )
#      17 for i in range(num_gens):
# ---> 18     data_sampler.generate_data(save_path=save_path, max_iters=None)
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py:66, in Textworld_Sampling_Manager.generate_data(self, save_path, max_iters, print_every)
#      64 while any(self.still_generating) and (max_iters is None or iters < max_iters):
#      65     iters += 1
# ---> 66     self._generate_samples()
#      67     # Print updates
#      68     if iters % print_every == 0:
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/util.py:99, in Textworld_Sampling_Manager._generate_samples(self)
#      96 if self.still_generating[arg_idx] == False:
#      97     continue
# ---> 99 self.wrapper.reset_env()
#     100 sampled_indices = self._get_sample_indices(self.wrapper.game_state.full_gold_path, args)
#     102 # Generate our data
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/sequential_decision_processors/data/textworld/raw/utils/env_wrappers.py:295, in Scienceworld_Wrapper_Env.reset_env(self)
#     293 def reset_env(self):
#     294     with silent_io():
# --> 295         env_response, env_state = self.env.reset()
#     296     self.game_state.full_gold_path = self.env.get_gold_action_sequence()
#     297     self._update_metadata(env_state=env_state, initial_state=True)
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/scienceworld/scienceworld.py:140, in ScienceWorldEnv.reset(self)
#     137 def reset(self) -> Tuple[str, Dict[str, Any]]:
#     138     ''' Resets the simulator back to the first move (the output of "look around" is returned) '''
# --> 140     self.server.reset()
#     142     # Reset last step score (used to calculate reward from current-previous score)
#     143     self.lastStepScore = 0
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1361, in JavaMember.__call__(self, *args)
#    1354 args_command, temp_args = self._build_args(*args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# -> 1361 answer = self.gateway_client.send_command(command)
#    1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#
# File ~/Desktop/UCSD/Research/sequential-decision-processors/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1104, in GatewayClient.send_command(self, command, retry, binary)
#    1102         logger.info("Shutting down the current connection {0}".format(connection))
#    1103         # The ports are reversed for JVM side of the connection.
# -> 1104         connection.shutdown_socket(local_addr[1], remote_addr[1])
#    1106     raise
#    1108 return response
#
# AttributeError: 'GatewayConnection' object has no attribute 'shutdown_socket'

# %% [markdown]
# ### Play around with SW

# %%
test_scienceworld_wrapper = True

if test_scienceworld_wrapper:
    scienceworld_wrapper = util.Scienceworld_Wrapper_Env()
    scienceworld_wrapper.load_env(randomize_gen_args=True)

    while not scienceworld_wrapper.game_state.done:
        done = scienceworld_wrapper.step_env()
        if scienceworld_wrapper.game_state.moves == 5:
            print(scienceworld_wrapper.get_env_state(full_state=True))
        else:
            print(scienceworld_wrapper.get_env_state(full_state=False))
# Out:
# [('User', 'open door to hallway'), ('Environment', 'The door is now open. Score: 0/100')]
# [('User', 'go to hallway'), ('Environment', 'You move to the hallway. Score: 25/100')]
# [('User', 'open door to greenhouse'), ('Environment', 'The door is now open. Score: 25/100')]
# [('User', 'go to greenhouse'), ('Environment', 'You move to the greenhouse. Score: 25/100')]
# [('Full Observation', "Move 5 | Score = 25/100\nActionable Verbs: ['activate', 'close', 'connect OBJ to', 'deactivate', 'disconnect', 'dunk OBJ in', 'eat', 'flush', 'focus on', 'go', 'inventory', 'look around', 'look at', 'look in', 'mix', 'move OBJ to', 'open', 'pick up', 'pour OBJ in', 'put down', 'read', 'task', 'use OBJ on', 'wait', 'wait1']\nObjective: Your task is to find the animal with the shortest life span.  The animals are in the 'outside' location.  Focus on the animal with the shortest life span.\nLocation: Greenhouse\nInventory: In your inventory, you see:\n\tan orange\n\nCurrent Observation: This room is called the greenhouse. In it, you see: \n\tthe agent\n\ta substance called air\n\ta bee hive. The bee hive door is closed. \n\ta jug (containing nothing)\n\ta sink, which is turned off. In the sink is: nothing.\nYou also see:\n\tA door to the hallway (that is open)\n\tA door to the outside (that is open)\n\n")]
# [('User', 'go to outside'), ('Environment', 'You move to the outside. Score: 50/100')]
# [('User', 'focus on chameleon'), ('Environment', 'You focus on the chameleon egg. Score: 100/100')]

# %%
# Pretty print helper
def list_tasks(env: ScienceWorldEnv, print_tasks=False) -> List[str]:
    tasks = env.get_task_names()
    for i, t in enumerate(tasks):
        vars = env.get_max_variations(t)
        if print_tasks:
            print(f"{i:2d} [{vars:>4}]: {t}")
    return tasks

# Optionally can print out our task list
print_tasks = True

if print_tasks:
    scienceworld_wrapper = util.Scienceworld_Wrapper_Env()
    tasks = list_tasks(scienceworld_wrapper.env, print_tasks=True)
# Out:
#  0 [  30]: boil
#  1 [  30]: change-the-state-of-matter-of
#  2 [  32]: chemistry-mix
#  3 [  36]: chemistry-mix-paint-secondary-color
#  4 [  36]: chemistry-mix-paint-tertiary-color
#  5 [ 300]: find-animal
#  6 [ 300]: find-living-thing
#  7 [ 300]: find-non-living-thing
#  8 [ 300]: find-plant
#  9 [  30]: freeze
# 10 [ 126]: grow-fruit
# 11 [ 126]: grow-plant
# 12 [  14]: identify-life-stages-1
# 13 [  10]: identify-life-stages-2
# 14 [ 168]: inclined-plane-determine-angle
# 15 [1386]: inclined-plane-friction-named-surfaces
# 16 [ 162]: inclined-plane-friction-unnamed-surfaces
# 17 [ 125]: lifespan-longest-lived
# 18 [ 125]: lifespan-longest-lived-then-shortest-lived
# 19 [ 125]: lifespan-shortest-lived
# 20 [ 436]: measure-melting-point-known-substance
# 21 [ 300]: measure-melting-point-unknown-substance
# 22 [  30]: melt
# 23 [ 120]: mendelian-genetics-known-plant
# 24 [ 480]: mendelian-genetics-unknown-plant
# 25 [  20]: power-component
# 26 [  20]: power-component-renewable-vs-nonrenewable-energy
# 27 [ 900]: test-conductivity
# 28 [ 600]: test-conductivity-of-unknown-substances
# 29 [ 540]: use-thermometer

# %%
test_playable_sw = True

# Create our wrapper
scienceworld_wrapper = util.Scienceworld_Wrapper_Env()

if test_playable_sw:
    play_scienceworld = True

    task_idx = 8
    tasks = list_tasks(scienceworld_wrapper.env, print_tasks=False)
    task_name = tasks[task_idx]
    task_variation_number = 0
    
    print(f"Loading task #{task_idx}: {task_name}.")
    
    scienceworld_wrapper.load_env(
        randomize_gen_args=False,
        task_args=(task_name, task_variation_number, "")
    )

    util.print_env_state(scienceworld_wrapper.get_env_state(full_state=True))    
    
    # Main play loop
    done = False
    while not done:
        if play_scienceworld:
            command = input("> ")
        else:
            command = None
        if command == "stop":
            break
        done = scienceworld_wrapper.step_env(command)
        util.print_env_state(scienceworld_wrapper.get_env_state(full_state=False))
# Out:
# Loading task #8: find-plant.
# Full Observation: Move 0 | Score = 0/100
# Actionable Verbs: ['activate', 'close', 'connect OBJ to', 'deactivate', 'disconnect', 'dunk OBJ in', 'eat', 'flush', 'focus on', 'go', 'inventory', 'look around', 'look at', 'look in', 'mix', 'move OBJ to', 'open', 'pick up', 'pour OBJ in', 'put down', 'read', 'task', 'use OBJ on', 'wait', 'wait1']
# Objective: Your task is to find a(n) plant. First, focus on the thing. Then, move it to the red box in the kitchen.
# Location: Hallway
# Inventory: In your inventory, you see:
# 	an orange
#
# Current Observation: This room is called the hallway. In it, you see:
# 	the agent
# 	a substance called air
# 	a picture
# You also see:
# 	A door to the art studio (that is closed)
# 	A door to the bedroom (that is closed)
# 	A door to the greenhouse (that is closed)
# 	A door to the kitchen (that is closed)
# 	A door to the living room (that is closed)
# 	A door to the workshop (that is closed)
#
#
#
#
# User: open door to greenhouse
#
#
# Environment: The door is now open. Score: 8/100
#
#
# User: go to greenhouse
#
#
# Environment: You move to the greenhouse. Score: 17/100
#
#
# User: look
#
#
# Environment: This room is called the greenhouse. In it, you see:
# 	the agent
# 	a substance called air
# 	a bee hive. The bee hive door is closed.
# 	a flower pot 2 (containing nothing)
# 	a flower pot 3 (containing a pea plant in the adult stage with a tall height, soil)
# 	a flower pot 6 (containing a apple tree in the adult stage, soil)
# 	a flower pot 7 (containing nothing)
# 	a flower pot 8 (containing a cherry tree in the adult stage, soil)
# 	a jug (containing nothing)
# 	a shovel
# 	a sink, which is turned off. In the sink is: nothing.
# You also see:
# 	A door to the hallway (that is open)
# 	A door to the outside (that is closed) Score: 17/100
#
#
# User: focus on pea plant
#
#
# Environment: You focus on the pea plant. Score: 67/100
#
#
# User: take pea plant
#
#
# Environment: You move the pea plant to the inventory. Score: 75/100
#
#
# User: open door to outside
#
#
# Environment: The door is now open. Score: 75/100
#
#
# User: go outside
#
#
# Environment: You move to the outside. Score: 75/100
#
#
# User: look
#
#
# Environment: This outside location is called the outside. Here you see:
# 	the agent
# 	a substance called air
# 	an axe
# 	a blue jay egg
# 	a butterfly egg
# 	a dove egg
# 	a fire pit (containing nothing)
# 	a fountain (containing a substance called water)
# 	the ground
# 	a substance called wood
# You also see:
# 	A door to the foundry (that is closed)
# 	A door to the greenhouse (that is open)
# 	A door to the kitchen (that is closed) Score: 75/100
#
#
# User: open door to kitchen
#
#
# Environment: The door is now open. Score: 75/100
#
#
# User: go to kitchen
#
#
# Environment: You move to the kitchen. Score: 83/100
#
#
# User: look
#
#
# Environment: This room is called the kitchen. In it, you see:
# 	the agent
# 	a substance called air
# 	a chair. On the chair is: nothing.
# 	a counter. On the counter is: a bowl (containing a red apple, a banana, an orange, a potato), a drawer.
# 	a cupboard. The cupboard door is closed.
# 	a freezer. The freezer door is closed.
# 	a fridge. The fridge door is closed.
# 	a glass jar (containing a substance called sodium chloride)
# 	a lighter
# 	a oven, which is turned off. The oven door is closed.
# 	a painting
# 	a red box (containing nothing)
# 	a sink, which is turned off. In the sink is: nothing.
# 	a substance called soap
# 	a stopwatch, which is deactivated.
# 	a stove, which is turned off. On the stove is: nothing.
# 	a table. On the table is: a glass cup (containing nothing).
# 	a thermometer, currently reading a temperature of 10 degrees celsius
# You also see:
# 	A door to the bathroom (that is closed)
# 	A door to the hallway (that is closed)
# 	A door to the outside (that is open) Score: 83/100
#
#
# User: move pea plant to red box
#
#
# Environment: You move the pea plant to the red box. Score: 100/100

# %% [markdown]
# # Other Helpers

# %% [markdown]
# ### Code to check the distribution of our move sampling

# %%
# from collections import deque, Counter
# import math, random

# multi_sample_args = util.SamplingArgs(
#     name="Test Multi",
#     max_samples_per_env=8,
#     rollout_length=5,
#     max_step_overlap=1
# )
# single_sample_args = util.SamplingArgs(
#     name="Test Single",
#     max_samples_per_env=20,
#     rollout_length=1,
#     max_step_overlap=0
# )


# def _get_sample_indices(self, gold_path: List[str], sampling_args) -> deque[int]:
#     # params
#     L = math.ceil(sampling_args.rollout_length / 2)
#     d = max(1, L - int(sampling_args.max_step_overlap))
#     U = len(gold_path)             # latest allowed start
#     if U < 0: return deque()

#     # random lattice offset to avoid 0-spike
#     o = random.randint(0, min(d - 1, max(0, U)))
#     cap = 1 + (U - o) // d
#     n = min(int(sampling_args.max_samples_per_env), cap)
#     if n <= 0: return deque()
#     if n == 1: return deque([random.randint(o, U)])

#     # slack after tight pack at o, o+d, ...
#     S = U - (o + d * (n - 1))
#     if S <= 0: return deque([o + i * d for i in range(n)])

#     # stars-and-bars over (lead, inter..., tail) summing to S
#     cuts = sorted(random.sample(range(1, S + n), n))
#     prev = 0; parts = []
#     for c in cuts + [S + n]:
#         parts.append(c - prev - 1); prev = c
#     lead, inter = parts[0], parts[1:n]

#     xs, acc = [], o + lead
#     for i in range(n):
#         xi = acc + i * d
#         xs.append(xi)
#         if i < n - 1: acc += inter[i]

#     assert all(0 <= x <= U for x in xs)
#     assert all(xs[i+1] - xs[i] >= d for i in range(n - 1))
#     return deque(xs)



# # ---- Simulation & plotting ----
# def simulate_and_plot_move_index_freqs(num_envs=10000, min_len=30, max_len=60, seed=0, sampler=None):
#     import random, matplotlib.pyplot as plt
#     if sampler is None:
#         sampler = lambda gp, args: _get_sample_indices(None, gp, args)  # your exact signature
#     random.seed(seed)
#     single = [0]*(max_len+1); multi = [0]*(max_len+1)
#     for _ in range(num_envs):
#         L = random.randint(min_len, max_len); gp = ['a']*L
#         for x in sampler(gp, single_sample_args):
#             if 0 <= x <= max_len: single[x] += 1
#         for x in sampler(gp, multi_sample_args):
#             if 0 <= x <= max_len:  multi[x]  += 1
#     xs = range(max_len+1)
#     print(single)
#     print(multi)
#     plt.figure(); plt.plot(xs, single, label="single"); plt.plot(xs, multi, label="multi")
#     plt.xlabel("Move index (0-based)"); plt.ylabel("Frequency"); plt.legend(); plt.tight_layout(); plt.show()

# simulate_and_plot_move_index_freqs()
